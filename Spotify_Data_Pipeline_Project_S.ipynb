# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="", client_secret="")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/5Rrf7mqN8uus2AaQQQNdc1"

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0]

# %%
data = sp.playlist_tracks("5Rrf7mqN8uus2AaQQQNdc1")

# %%
data['items']
# Out:
# [{'added_at': '2024-03-19T00:42:27Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/kieron'},
#    'href': 'https://api.spotify.com/v1/users/kieron',
#    'id': 'kieron',
#    'type': 'user',
#    'uri': 'spotify:user:kieron'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '2Pj2kZM5XpyIeyFBTAVulL'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Pat Garrett & Billy The Kid (Soundtrack From The Motion Picture)'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '1973-07-13'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 10

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/2Pj2kZM5XpyIeyFBTAVulL'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '2Pj2kZM5XpyIeyFBTAVulL',
#   'name': 'Pat Garrett & Billy The Kid (Soundtrack From The Motion Picture)',
#   'release_date': '1973-07-13',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/2Pj2kZM5XpyIeyFBTAVulL'},
#  {'album_id': '0ETFjACtuP2ADo6LFhL6HN',
#   'name': 'Abbey Road (Remastered)',
#   'release_date': '1969-09-26',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/0ETFjACtuP2ADo6LFhL6HN'},
#  {'album_id': '7nXJ5k4XgRj5OLg9m8V3zc',
#   'name': 'Purple Rain',
#   'release_date': '1984-06-25',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/7nXJ5k4XgRj5OLg9m8V3zc'},
#  {'album_id': '43Axle5un9qnVUp113oHzB',
#   'name': 'Favorites',
#   'release_date': '2008-08-04',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/43Axle5un9qnVUp113oHzB'},
#  {'album_id': '1YYEC5hLwDbQPtErSBD223',
#   'name': 'The Rolling Stones Singles Collection: The London Years (Remastered)',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2024-03-19T00:42:27Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/kieron'},
#   'href': 'https://api.spotify.com/v1/users/kieron',
#   'id': 'kieron',
#   'type': 'user',
#   'uri': 'spotify:user:kieron'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '74ASZWbe4lXaubB36ztrGX',
#   'artist_name': 'Bob Dylan',
#   'external_url': 'https://api.spotify.com/v1/artists/74ASZWbe4lXaubB36ztrGX'},
#  {'artist_id': '3WrFJ7ztbogyGnTHbHJFl2',
#   'artist_name': 'The Beatles',
#   'external_url': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2'},
#  {'artist_id': '5a2EaR3hamoenG9rDuVn8j',
#   'artist_name': 'Prince',
#   'external_url': 'https://api.spotify.com/v1/artists/5a2EaR3hamoenG9rDuVn8j'},
#  {'artist_id': '3koiLjNrgRTNbOwViDipeA',
#   'artist_name': 'Marvin Gaye',
#   'external_url': 'https://api.spotify.com/v1/artists/3koiLjNrgRTNbOwViDipeA'},
#  {'artist_id': '22bE4uQ6baNwSHPVcDxLCe',
#   'artist_name': 'The Rolling Stones',
#   'external_url': 'https://api.spotify.com/v1/artists/22bE4uQ6baNwSHPVcDxLCe'},
#  {'artist_id': '4x1nvY2FN8jxqAFA0DA02H',
#   'artist_name': 'John Lennon',
#   'external_url': 'https://api.spotify.com/v1/artists/4x1nvY2FN8jxqAFA0DA02H'},
#  {'artist_id': '1ThoqLcyIYvZn7iWbj8fsj',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  2Pj2kZM5XpyIeyFBTAVulL  Pat Garrett & Billy The Kid (Soundtrack From T...
# 1  0ETFjACtuP2ADo6LFhL6HN                            Abbey Road (Remastered)
# 2  7nXJ5k4XgRj5OLg9m8V3zc                                        Purple Rain
# 3  43Axle5un9qnVUp113oHzB                                          Favorites
# 4  1YYEC5hLwDbQPtErSBD223  The Rolling Stones Singles Collection: The Lon...
#
#   release_date  total_tracks  \
# 0   1973-07-13            10
# 1   1969-09-26            17
# 2   1984-06-25             9
# 3   2008-08-04            15
# 4   1989-08-15            58
#
#                                                  url
# 0  https://open.spotify.com/album/2Pj2kZM5XpyIeyF...
# 1  https://open.spotify.com/album/0ETFjACtuP2ADo6...
# 2  https://open.spotify.com/album/7nXJ5k4XgRj5OLg...
# 3  https://open.spotify.com/album/43Axle5un9qnVUp...
# 4  https://open.spotify.com/album/1YYEC5hLwDbQPtE...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                                          song_name  \
# 0  6HSXNV0b4M4cLJ7ljgVVeh                          Knockin' On Heaven's Door
# 1  6dGnYIeXmHdcikdzNNDMm2               Here Comes The Sun - Remastered 2009
# 2  54X78diSLoUDI3joC2bjMz                                        Purple Rain
# 3  42PyxnviKRfOa8z39g8aZj                                    What's Going On
# 4  57J2znxukXsXzS3XPuZ1TG  (I Can't Get No) Satisfaction - Mono Version /...
#
#    duration_ms                                                url  popularity  \
# 0       149880  https://open.spotify.com/track/6HSXNV0b4M4cLJ7...          80
# 1       185733  https://open.spotify.com/track/6dGnYIeXmHdcikd...          82
# 2       520786  https://open.spotify.com/track/54X78diSLoUDI3j...          14
# 3       233293  https://open.spotify.com/track/42PyxnviKRfOa8z...           0
# 4       222840  https://open.spotify.com/track/57J2znxukXsXzS3...           0
#
# ...

# %%
artist_df.head()
# Out:
#                 artist_id         artist_name  \
# 0  74ASZWbe4lXaubB36ztrGX           Bob Dylan
# 1  3WrFJ7ztbogyGnTHbHJFl2         The Beatles
# 2  5a2EaR3hamoenG9rDuVn8j              Prince
# 3  3koiLjNrgRTNbOwViDipeA         Marvin Gaye
# 4  22bE4uQ6baNwSHPVcDxLCe  The Rolling Stones
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/74ASZWbe4lX...
# 1  https://api.spotify.com/v1/artists/3WrFJ7ztbog...
# 2  https://api.spotify.com/v1/artists/5a2EaR3hamo...
# 3  https://api.spotify.com/v1/artists/3koiLjNrgRT...
# 4  https://api.spotify.com/v1/artists/22bE4uQ6baN...

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  2Pj2kZM5XpyIeyFBTAVulL  Pat Garrett & Billy The Kid (Soundtrack From T...
# 1  0ETFjACtuP2ADo6LFhL6HN                            Abbey Road (Remastered)
# 2  7nXJ5k4XgRj5OLg9m8V3zc                                        Purple Rain
# 3  43Axle5un9qnVUp113oHzB                                          Favorites
# 4  1YYEC5hLwDbQPtErSBD223  The Rolling Stones Singles Collection: The Lon...
#
#   release_date  total_tracks  \
# 0   1973-07-13            10
# 1   1969-09-26            17
# 2   1984-06-25             9
# 3   2008-08-04            15
# 4   1989-08-15            58
#
#                                                  url
# 0  https://open.spotify.com/album/2Pj2kZM5XpyIeyF...
# 1  https://open.spotify.com/album/0ETFjACtuP2ADo6...
# 2  https://open.spotify.com/album/7nXJ5k4XgRj5OLg...
# 3  https://open.spotify.com/album/43Axle5un9qnVUp...
# 4  https://open.spotify.com/album/1YYEC5hLwDbQPtE...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'], errors='coerce', format='%Y-%m-%d', infer_datetime_format=True)
# Out:
# <ipython-input-47-a7a0b964126d>:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   album_df['release_date'] = pd.to_datetime(album_df['release_date'], errors='coerce', format='%Y-%m-%d', infer_datetime_format=True)

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
